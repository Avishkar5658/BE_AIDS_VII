# %%
NAME: Aher Swami Sandip
ROLL NO. 01
COURSE: AI&DS
CLASS: BE
SUB:Computer Laboratory-I (DMV)

# %%
pip install folium
# Out:
# Collecting foliumNote: you may need to restart the kernel to use updated packages.
#
#   Downloading folium-0.18.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from folium) (1.24.4)
# Requirement already satisfied: requests in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\old ssd\anaconda3\anaconda\envs\swami\lib\site-packages (from requests->folium) (2024.8.30)
# Downloading folium-0.18.0-py2.py3-none-any.whl (108 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.1 folium-0.18.0 xyzservices-2025.4.0

# %% [markdown]
# ## Interacting with Web APIs

# %%
# Problem Statement: Analyzing Weather Data from OpenWeatherMap API 
# Dataset: Weather data retrieved from OpenWeatherMap API 
# Description: The goal is to interact with the OpenWeatherMap API to retrieve weather data 
# for a specific location and perform data modeling and visualization to analyze weather 
# patterns over time. 
# Tasks to Perform:

# %% [markdown]
# ### 1. Register and obtain API key from OpenWeatherMap.
# ### 2. Interact with the OpenWeatherMap API using the API key to retrieve weather data for a specific location.

# %%
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
import requests

api_key = '18896d417b61718248835471bedf9b54'
location = 'Pune' 
url = f'http://api.openweathermap.org/data/2.5/weather?q={location}&appid={api_key}'

response = requests.get(url)
weather_data = response.json()

# Display the retrieved weather data
print(weather_data)
# Out:
# {'coord': {'lon': 73.8553, 'lat': 18.5196}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 293.78, 'feels_like': 294.35, 'temp_min': 293.78, 'temp_max': 293.78, 'pressure': 1014, 'humidity': 94, 'sea_level': 1014, 'grnd_level': 941}, 'visibility': 10000, 'wind': {'speed': 2.83, 'deg': 259, 'gust': 4.31}, 'clouds': {'all': 13}, 'dt': 1759685511, 'sys': {'country': 'IN', 'sunrise': 1759625745, 'sunset': 1759668606}, 'timezone': 19800, 'id': 1259229, 'name': 'Pune', 'cod': 200}

# %%
# Extract relevant weather attributes
temperature = weather_data['main']['temp'] - 273.15  # Convert from Kelvin to Celsius
humidity = weather_data['main']['humidity']
wind_speed = weather_data['wind']['speed']
weather_description = weather_data['weather'][0]['description']

# %% [markdown]
# ### 3. Extract relevant weather attributes such as temperature, humidity, wind speed, and precipitation from the API response.

# %%
print(f"Temperature: {temperature}°C")
print(f"Humidity: {humidity}%")
print(f"Wind Speed: {wind_speed} m/s")
print(f"Weather Description: {weather_description}")
# Out:
# Temperature: 20.629999999999995°C
# Humidity: 94%
# Wind Speed: 2.83 m/s
# Weather Description: few clouds

# %%
import pandas as pd
from datetime import datetime

# Example data collection over time
data = {
    'datetime': [datetime.now()],
    'temperature': [temperature],
    'humidity': [humidity],
    'wind_speed': [wind_speed],
    'weather_description': [weather_description]
}

df = pd.DataFrame(data)
print(f"Temperature: {temperature}°C")
print(f"Humidity: {humidity}%")
print(f"Wind Speed: {wind_speed} m/s")
print(f"Weather Description: {weather_description}")
df.head()
# Out:
# Temperature: 20.629999999999995°C
# Humidity: 94%
# Wind Speed: 2.83 m/s
# Weather Description: few clouds
#                     datetime  temperature  humidity  wind_speed  \
# 0 2025-10-05 23:06:28.646348        20.63        94        2.83
#
#   weather_description
# 0          few clouds

# %%
# For example, calculating average values
average_temperature = df['temperature'].mean()
average_humidity = df['humidity'].mean()

print(f"Average Temperature: {average_temperature}°C")
print(f"Average Humidity: {average_humidity}%")
# Out:
# Average Temperature: 20.629999999999995°C
# Average Humidity: 94.0%

# %% [markdown]
# ### 4. Clean and preprocess the retrieved data, handling missing values or inconsistent formats.

# %%
df.isnull().sum()
# Out:
# datetime               0
# temperature            0
# humidity               0
# wind_speed             0
# weather_description    0
# dtype: int64

# %%
df.dtypes
# Out:
# datetime               datetime64[ns]
# temperature                   float64
# humidity                        int64
# wind_speed                    float64
# weather_description            object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df["weather_description"] = encoder.fit_transform(df["weather_description"])
df["datetime"] = encoder.fit_transform(df["datetime"])

# %% [markdown]
# ### 5. Perform data modeling to analyze weather patterns, such as calculating average temperature, maximum/minimum values, or trends over time.

# %%
average_temp = df["temperature"].mean()  # Replace "Temperature" with your actual column name
print(f"Average Temperature: {average_temp:.2f}")  # Format to two decimal places
# Out:
# Average Temperature: 20.63

# %%
max_temp = df["temperature"].max()
min_temp = df["temperature"].min()

print(f"Maximum Temperature: {max_temp:.2f}")
print(f"Minimum Temperature: {min_temp:.2f}")
# Out:
# Maximum Temperature: 20.63
# Minimum Temperature: 20.63

# %%
df["datetime"] = pd.to_datetime(df["datetime"])  # Assuming you have a "date" column

# Daily average temperature
daily_average_temp = df.resample("D", on="datetime")["temperature"].mean()  # Resample by day
print(daily_average_temp.head())  # Print first few days

# You can similarly calculate weekly, monthly, or yearly averages by changing "D" to "W", "M", or "Y" in resample
# Out:
# datetime
# 1970-01-01    20.63
# Freq: D, Name: temperature, dtype: float64

# %%
#trends over time
# Line chart for temperature over time
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
daily_average_temp.plot( marker='o',linestyle='-')
plt.title('Temperature Over Time')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()
# Out:
# D:\Old ssd\Anaconda3\Anaconda\envs\swami\lib\site-packages\pandas\plotting\_matplotlib\core.py:1401: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(left, right)

# %% [markdown]
# ### 6. Visualize the weather data using appropriate plots, such as line charts, bar plots, or scatter plots, to represent
# ### temperature changes, precipitation levels, or wind speed variations.

# %%
df.columns
# Out:
# Index(['datetime', 'temperature', 'humidity', 'wind_speed',
#        'weather_description'],
#       dtype='object')

# %%
# Temperature Plot
plt.subplot(2, 1, 1)
plt.plot(df['datetime'], df['temperature'], marker='o', color='tab:blue')
plt.title('Temperature Over Time')
plt.xlabel('datetime')
plt.ylabel('temperature')
plt.xticks(rotation=45)
# Out:
# (array([-731., -549., -365., -184.,    0.,  181.,  365.,  546.,  730.]),
#  [Text(-731.0, 0, '1968-01'),
#   Text(-549.0, 0, '1968-07'),
#   Text(-365.0, 0, '1969-01'),
#   Text(-184.0, 0, '1969-07'),
#   Text(0.0, 0, '1970-01'),
#   Text(181.0, 0, '1970-07'),
#   Text(365.0, 0, '1971-01'),
#   Text(546.0, 0, '1971-07'),
#   Text(730.0, 0, '1972-01')])

# %%
# Wind Speed Scatter Plot
plt.subplot(2, 1, 2)
plt.scatter(df['datetime'], df['wind_speed'], color='tab:green')
plt.title('Wind Speed Over Time')
plt.xlabel('datetime')
plt.ylabel('wind_speed')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7. Apply data aggregation techniques to summarize weather statistics by specific time
# ### periods (e.g., daily, monthly, seasonal).

# %%
print(df.columns)
# Out:
# Index(['datetime', 'temperature', 'humidity', 'wind_speed',
#        'weather_description'],
#       dtype='object')

# %%
# Convert 'Date' to datetime format
df["datetime"] = pd.to_datetime(df["datetime"])  


# Set 'Date' as the index
df.set_index('datetime', inplace=True)

# Resample and aggregate data
daily_summary = df.resample('D').agg({
    'temperature': ['mean', 'max', 'min'],
    'wind_speed': ['mean', 'max', 'min']
})

monthly_summary = df.resample('ME').agg({
    'temperature': ['mean', 'max', 'min'],
    'wind_speed': ['mean', 'max', 'min']
})

# Print the summary statistics
print("Daily Summary:\n", daily_summary)
print("\nMonthly Summary:\n", monthly_summary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Old ssd\Anaconda3\Anaconda\envs\swami\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File D:\Old ssd\Anaconda3\Anaconda\envs\swami\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Old ssd\Anaconda3\Anaconda\envs\swami\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Convert 'Date' to datetime format
# ----> 2 df["datetime"] = pd.to_datetime(df["datetime"])
#       5 # Set 'Date' as the index
#       6 df.set_index('datetime', inplace=True)
#
# File D:\Old ssd\Anaconda3\Anaconda\envs\swami\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File D:\Old ssd\Anaconda3\Anaconda\envs\swami\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'datetime'

# %%
# Plot the aggregated data
plt.figure(figsize=(14, 10))

# Daily Temperature Summary
plt.subplot(2, 1, 1)
plt.plot(daily_summary.index, daily_summary[('temperature', 'mean')], marker='o', color='tab:blue', label='Mean Temperature')
plt.fill_between(daily_summary.index, daily_summary[('temperature', 'min')], daily_summary[('temperature', 'max')], color='tab:blue', alpha=0.2)
plt.title('Daily Temperature Summary')
plt.xlabel('date')
plt.ylabel('temperature')
plt.legend()
plt.xticks(rotation=45)
# Out:
# (array([-731., -549., -365., -184.,    0.,  181.,  365.,  546.,  730.]),
#  [Text(-731.0, 0, '1968-01'),
#   Text(-549.0, 0, '1968-07'),
#   Text(-365.0, 0, '1969-01'),
#   Text(-184.0, 0, '1969-07'),
#   Text(0.0, 0, '1970-01'),
#   Text(181.0, 0, '1970-07'),
#   Text(365.0, 0, '1971-01'),
#   Text(546.0, 0, '1971-07'),
#   Text(730.0, 0, '1972-01')])

# %%
# Monthly Temperature Summary
plt.subplot(2, 1, 2)
plt.plot(monthly_summary.index, monthly_summary[('temperature', 'mean')], marker='o', color='tab:green', label='Mean Temperature')
plt.fill_between(monthly_summary.index, monthly_summary[('temperature', 'min')], monthly_summary[('temperature', 'max')], color='tab:green', alpha=0.2)
plt.title('Monthly Temperature Summary')
plt.xlabel('datetime')
plt.ylabel('temperature')
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Monthly Temperature Summary
#       2 plt.subplot(2, 1, 2)
# ----> 3 plt.plot(monthly_summary.index, monthly_summary[('temperature', 'mean')], marker='o', color='tab:green', label='Mean Temperature')
#       4 plt.fill_between(monthly_summary.index, monthly_summary[('temperature', 'min')], monthly_summary[('temperature', 'max')], color='tab:green', alpha=0.2)
#       5 plt.title('Monthly Temperature Summary')
#
# NameError: name 'monthly_summary' is not defined

# %% [markdown]
# ### 8. Incorporate geographical information, if available, to create maps or geospatial
# ### visualizations representing weather patterns across different locations.

# %%
import requests
import pandas as pd
import folium

# Define a list of locations
locations = ['Pune', 'Mumbai', 'Delhi', 'Chennai', 'Kolkata']

# Fetch weather data for multiple locations
api_key = '18896d417b61718248835471bedf9b54'
weather_data = []

for location in locations:
    url = f'http://api.openweathermap.org/data/2.5/weather?q={location}&appid={api_key}'
    response = requests.get(url)
    data = response.json()
    weather_info = {
        'Location': location,
        'Latitude': data['coord']['lat'],
        'Longitude': data['coord']['lon'],
        'Temperature (C)': data['main']['temp'] - 273.15,
        'Wind Speed (m/s)': data['wind']['speed']
    }
    weather_data.append(weather_info)

# Print the raw weather data to debug
print("Weather Data:\n", weather_data)

# Create a DataFrame
df = pd.DataFrame(weather_data)

# Print the DataFrame to debug
print("\nDataFrame:\n", df)

# Create a map centered around India
m = folium.Map(location=[20.5937, 78.9629], zoom_start=5)

# Add markers to the map
for i, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=(
            f"Location: {row['Location']}<br>"
            f"Temperature (C): {row['Temperature (C)']:.2f}<br>"
            f"Wind Speed (m/s): {row['Wind Speed (m/s)']:.2f}"
        ),
        tooltip=row['Location']
    ).add_to(m)

# Save the map to an HTML file
m.save('weather_map.html')

# Display the map
m
# Out:
# Weather Data:
#  [{'Location': 'Pune', 'Latitude': 18.5196, 'Longitude': 73.8553, 'Temperature (C)': 20.629999999999995, 'Wind Speed (m/s)': 2.83}, {'Location': 'Mumbai', 'Latitude': 19.0144, 'Longitude': 72.8479, 'Temperature (C)': 26.870000000000005, 'Wind Speed (m/s)': 3.99}, {'Location': 'Delhi', 'Latitude': 28.6667, 'Longitude': 77.2167, 'Temperature (C)': 29.680000000000007, 'Wind Speed (m/s)': 2.09}, {'Location': 'Chennai', 'Latitude': 13.0878, 'Longitude': 80.2785, 'Temperature (C)': 28.99000000000001, 'Wind Speed (m/s)': 4.46}, {'Location': 'Kolkata', 'Latitude': 22.5697, 'Longitude': 88.3697, 'Temperature (C)': 26.379999999999995, 'Wind Speed (m/s)': 1.29}]
#
# DataFrame:
#    Location  Latitude  Longitude  Temperature (C)  Wind Speed (m/s)
# 0     Pune   18.5196    73.8553            20.63              2.83
# 1   Mumbai   19.0144    72.8479            26.87              3.99
# 2    Delhi   28.6667    77.2167            29.68              2.09
# 3  Chennai   13.0878    80.2785            28.99              4.46
# 4  Kolkata   22.5697    88.3697            26.38              1.29
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de82ff8931adae104b446cafccf2ff62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de82ff8931adae104b446cafccf2ff62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de82ff8931adae104b446cafccf2ff62 = L.map(
#                 &quot;map_de82ff8931adae104b446cafccf2ff62&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dc08b81b0226084309e4237cbf0d24f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8dc08b81b0226084309e4237cbf0d24f.addTo(map_de82ff8931adae104b446cafccf2ff62);
#
#
#             var marker_5fa112e2b440774ec5a9438e5bab1088 = L.marker(
#                 [18.5196, 73.8553],
#                 {}
#             ).addTo(map_de82ff8931adae104b446cafccf2ff62);
#
#
#         var popup_e37d9fc9231f562c344316a51d1f4dba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67309618c88c9a48591e04fac6c50f81 = $(`&lt;div id=&quot;html_67309618c88c9a48591e04fac6c50f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: Pune&lt;br&gt;Temperature (C): 20.63&lt;br&gt;Wind Speed (m/s): 2.83&lt;/div&gt;`)[0];
#                 popup_e37d9fc9231f562c344316a51d1f4dba.setContent(html_67309618c88c9a48591e04fac6c50f81);
#
#
#
#         marker_5fa112e2b440774ec5a9438e5bab1088.bindPopup(popup_e37d9fc9231f562c344316a51d1f4dba)
#         ;
#
#
#
#
#             marker_5fa112e2b440774ec5a9438e5bab1088.bindTooltip(
#                 `&lt;div&gt;
#                      Pune
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d03e219b82ef377ded3b2b25563162e = L.marker(
#                 [19.0144, 72.8479],
#                 {}
#             ).addTo(map_de82ff8931adae104b446cafccf2ff62);
#
#
#         var popup_73f4c1e30d838d6d199b7c4d24563db2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6aa783b6803c68380e0ae733309cabef = $(`&lt;div id=&quot;html_6aa783b6803c68380e0ae733309cabef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: Mumbai&lt;br&gt;Temperature (C): 26.87&lt;br&gt;Wind Speed (m/s): 3.99&lt;/div&gt;`)[0];
#                 popup_73f4c1e30d838d6d199b7c4d24563db2.setContent(html_6aa783b6803c68380e0ae733309cabef);
#
#
#
#         marker_2d03e219b82ef377ded3b2b25563162e.bindPopup(popup_73f4c1e30d838d6d199b7c4d24563db2)
#         ;
#
#
#
#
#             marker_2d03e219b82ef377ded3b2b25563162e.bindTooltip(
#                 `&lt;div&gt;
#                      Mumbai
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e59b0b4e5275a4320e82a181d655be81 = L.marker(
#                 [28.6667, 77.2167],
#                 {}
#             ).addTo(map_de82ff8931adae104b446cafccf2ff62);
#
#
#         var popup_84051e054f86863e39aafe32ecb47dd5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5393a0a540647a57b4dcc5c6c13ae74 = $(`&lt;div id=&quot;html_c5393a0a540647a57b4dcc5c6c13ae74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: Delhi&lt;br&gt;Temperature (C): 29.68&lt;br&gt;Wind Speed (m/s): 2.09&lt;/div&gt;`)[0];
#                 popup_84051e054f86863e39aafe32ecb47dd5.setContent(html_c5393a0a540647a57b4dcc5c6c13ae74);
#
#
#
#         marker_e59b0b4e5275a4320e82a181d655be81.bindPopup(popup_84051e054f86863e39aafe32ecb47dd5)
#         ;
#
#
#
#
#             marker_e59b0b4e5275a4320e82a181d655be81.bindTooltip(
#                 `&lt;div&gt;
#                      Delhi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fe3247143b38ce46d25a817d9b7127c = L.marker(
#                 [13.0878, 80.2785],
#                 {}
#             ).addTo(map_de82ff8931adae104b446cafccf2ff62);
#
#
#         var popup_8892d90c45f4858f602f22f921cc5a55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e42c8a4c5c3cc272ce673f6aa8c2bd09 = $(`&lt;div id=&quot;html_e42c8a4c5c3cc272ce673f6aa8c2bd09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location: Chennai&lt;br&gt;Temperature (C): 28.99&lt;br&gt;Wind Speed (m/s): 4.46&lt;/div&gt;`)[0];
#                 popup_8892d90c45f4858f602f22f921cc5a55.setContent(html_e42c8a4c5c3cc272ce673f6aa8c2bd09);
#
#
#
#         marker_6fe3247143b38ce46d25a817d9b7127c.bindPopup(popup_8892d90c45f4858f602f22f921cc5a55)
#         ;
#
#
#
#
#             marker_6fe3247143b38ce46d25a817d9b7127c.bindT

# %% [markdown]
# ### 9. Explore and visualize relationships between weather attributes, such as temperature and humidity,
# ### using correlation plots or heatmaps.

# %%
import seaborn as sns
## Correlation Heatmap
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
